# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangeetha-122/projects-in-ML/blob/main/Copy_of_Welcome_To_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd

# %%
data =pd.read_csv("/content/eng_-french.csv")

# %%
data
# Out:
#               English words/sentences  \
# 0                                 Hi.
# 1                                Run!
# 2                                Run!
# 3                                Who?
# 4                                Wow!
# ...                               ...
# 97402  I wonder if Tom is having fun.
# 97403  I wonder if maybe I should go.
# 97404  I wonder if this really works.
# 97405  I wonder if you could do that.
# 97406               I wonder if you c
#
#                                French words/sentences
# 0                                              Salut!
# 1                                             Cours !
# 2                                            Courez !
# 3                                               Qui ?
# 4                                          Ça alors !
# ...                                               ...
# 97402              Je me demande si Tom s'amuse bien.
# 97403  Je me demande si je devrais peut-être y aller.
# 97404        Je me demande si ça fonctionne vraiment.
# 97405          Je me demande si tu pourrais faire ça.
# 97406                                             NaN
#
# [97407 rows x 2 columns]

# %%
data['English words/sentences count'] = data['English words/sentences'].str.split().str.len()
data['French words/sentences count '] = data['French words/sentences'].str.split().str.len()

# %%
data
# Out:
#               English words/sentences  \
# 0                                 Hi.
# 1                                Run!
# 2                                Run!
# 3                                Who?
# 4                                Wow!
# ...                               ...
# 97402  I wonder if Tom is having fun.
# 97403  I wonder if maybe I should go.
# 97404  I wonder if this really works.
# 97405  I wonder if you could do that.
# 97406               I wonder if you c
#
#                                French words/sentences  \
# 0                                              Salut!
# 1                                             Cours !
# 2                                            Courez !
# 3                                               Qui ?
# 4                                          Ça alors !
# ...                                               ...
# 97402              Je me demande si Tom s'amuse bien.
# 97403  Je me demande si je devrais peut-être y aller.
# 97404        Je me demande si ça fonctionne vraiment.
# 97405          Je me demande si tu pourrais faire ça.
# 97406                                             NaN
#
#        English words/sentences count  French words/sentences count
# 0                                  1                            1.0
# 1                                  1                            2.0
# 2                                  1                            2.0
# 3                                  1                            2.0
# 4                                  1                            3.0
# ...                              ...                            ...
# 97402                              7                            7.0
# 97403                              7                            9.0
# 97404                              6                            7.0
# 97405                              7                            8.0
# 97406                              5                            NaN
#
# [97407 rows x 4 columns]

# %%
data['English words/sentences'].str.split()
# Out:
# 0                                         [Hi.]
# 1                                        [Run!]
# 2                                        [Run!]
# 3                                        [Who?]
# 4                                        [Wow!]
#                           ...
# 97402    [I, wonder, if, Tom, is, having, fun.]
# 97403    [I, wonder, if, maybe, I, should, go.]
# 97404     [I, wonder, if, this, really, works.]
# 97405    [I, wonder, if, you, could, do, that.]
# 97406                   [I, wonder, if, you, c]
# Name: English words/sentences, Length: 97407, dtype: object

# %%
data['French words/sentences'].str.split()
# Out:
# 0                                    [Salut!]
# 1                                  [Cours, !]
# 2                                 [Courez, !]
# 3                                    [Qui, ?]
# 4                              [Ça, alors, !]
#                          ...
# 97179    [Je, comprends, votre, frustration.]
# 97350              [Je, ne, cherchais, rien.]
# 97373    [Demain, je, jouerai, au, football.]
# 97399    [Je, ne, tolérerai, aucune, erreur.]
# 97400          [Je, ne, le, tolèrerai, plus.]
# Name: French words/sentences, Length: 52606, dtype: object

# %%
data=data[(data['English words/sentences count']<6)&(data['French words/sentences count ']<6)]

# %%
data
# Out:
#               English words/sentences           French words/sentences  \
# 0                                 Hi.                           Salut!
# 1                                Run!                          Cours !
# 2                                Run!                         Courez !
# 3                                Who?                            Qui ?
# 4                                Wow!                       Ça alors !
# ...                               ...                              ...
# 97179  I understand your frustration.  Je comprends votre frustration.
# 97350  I wasn't looking for anything.            Je ne cherchais rien.
# 97373  I will play football tomorrow.   Demain je jouerai au football.
# 97399  I won't tolerate any mistakes.   Je ne tolérerai aucune erreur.
# 97400  I won't tolerate that anymore.         Je ne le tolèrerai plus.
#
#        English words/sentences count  French words/sentences count
# 0                                  1                            1.0
# 1                                  1                            2.0
# 2                                  1                            2.0
# 3                                  1                            2.0
# 4                                  1                            3.0
# ...                              ...                            ...
# 97179                              4                            4.0
# 97350                              5                            4.0
# 97373                              5                            5.0
# 97399                              5                            5.0
# 97400                              5                            5.0
#
# [52606 rows x 4 columns]

# %%
data=data.drop_duplicates()

# %%
data
# Out:
#               English words/sentences           French words/sentences  \
# 0                                 Hi.                           Salut!
# 1                                Run!                          Cours !
# 2                                Run!                         Courez !
# 3                                Who?                            Qui ?
# 4                                Wow!                       Ça alors !
# ...                               ...                              ...
# 97179  I understand your frustration.  Je comprends votre frustration.
# 97350  I wasn't looking for anything.            Je ne cherchais rien.
# 97373  I will play football tomorrow.   Demain je jouerai au football.
# 97399  I won't tolerate any mistakes.   Je ne tolérerai aucune erreur.
# 97400  I won't tolerate that anymore.         Je ne le tolèrerai plus.
#
#        English words/sentences count  French words/sentences count
# 0                                  1                            1.0
# 1                                  1                            2.0
# 2                                  1                            2.0
# 3                                  1                            2.0
# 4                                  1                            3.0
# ...                              ...                            ...
# 97179                              4                            4.0
# 97350                              5                            4.0
# 97373                              5                            5.0
# 97399                              5                            5.0
# 97400                              5                            5.0
#
# [52606 rows x 4 columns]

# %% [markdown]
# # **DIVIDING  DATA INTO TRAIN TEST VALIDATION**

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data,test_size=0.2)

# %%
train['English words/sentences count'].max()
# Out:
# 5

# %%
train["French words/sentences count "].max()
# Out:
# 5.0

# %%
train, valid = train_test_split(train,test_size=0.2)

# %% [markdown]
# # **WORD FREQUNCY**

# %%
freq_x=train['English words/sentences'].str.split(expand=True).stack().value_counts().reset_index()
freq_y=train['French words/sentences'].str.split(expand=True).stack().value_counts().reset_index()
freq_x.to_csv('English_freq.csv',index=False)
freq_y.to_csv('French_freq.csv',index=False)

# %%
freq_x=pd.read_csv('English_freq.csv')
freq_y=pd.read_csv('French_freq.csv')

# %%
freq_x
# Out:
#             index     0
# 0               I  5997
# 1             you  3307
# 2               a  3209
# 3              is  2808
# 4             the  2160
# ...           ...   ...
# 9858     college?     1
# 9859       skate?     1
# 9860       hello.     1
# 9861      runner.     1
# 9862  individual.     1
#
# [9863 rows x 2 columns]

# %%
freq_y
# Out:
#                index     0
# 0                  ?  5017
# 1                 Je  4617
# 2                 Il  2215
# 3                est  2212
# 4                pas  2183
# ...              ...   ...
# 15717      comédien.     1
# 15718  Réveillez-moi     1
# 15719   frustration.     1
# 15720       alarmés.     1
# 15721      distraits     1
#
# [15722 rows x 2 columns]

# %% [markdown]
# # **DATA PREPARATION**

# %%
d
